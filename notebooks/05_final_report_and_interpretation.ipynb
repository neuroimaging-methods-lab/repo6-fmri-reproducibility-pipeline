# %% [markdown]
# ##Final Report: Reliability, Reproducibility, and Inference in Task-fMRI
#
# This notebook synthesizes results from the full analysis pipeline, including data quality checks, first-level modeling, preprocessing sensitivity analysis, and statistical threshold comparisons.

# %%
import pandas as pd

# %%
summary = pd.DataFrame({
    "Analysis Component": [
        "Data Loading & QC",
        "First-Level GLM",
        "Smoothing Sensitivity",
        "Threshold Comparison"
    ],
    "Key Result": [
        "Valid 4D task-fMRI dataset with 10 task conditions and 128 volumes",
        "Meaningful sentence_reading vs sentence_listening activation contrast obtained",
        "Higher smoothing reduced peak z-scores and increased spatial spread",
        "Inference varied across uncorrected, FDR, and conservative thresholds"
    ]
})

summary
# Out:
#       Analysis Component                                         Key Result
# 0      Data Loading & QC  Valid 4D task-fMRI dataset with 10 task condit...
# 1        First-Level GLM  Meaningful sentence_reading vs sentence_listen...
# 2  Smoothing Sensitivity  Higher smoothing reduced peak z-scores and inc...
# 3   Threshold Comparison  Inference varied across uncorrected, FDR, and ...

# %% [markdown]
# # Key Findings
#
# ## 1. Experimental Design Matters
# The dataset contained multiple cognitive, sensory, and motor conditions, enabling rich task modeling.
#
# ## 2. GLM Successfully Captured Task Effects
# The contrast between sentence reading and sentence listening produced structured positive and negative activation patterns.
#
# ## 3. Preprocessing Choices Influence Results
# Increasing smoothing reduced local peak statistics while expanding cluster extent.
#
# ## 4. Statistical Thresholding Changes Interpretation
# More liberal thresholds retained more voxels, while stricter thresholds improved specificity.

# %%
results = pd.DataFrame({
    "Condition": ["0 mm smoothing", "5 mm smoothing", "8 mm smoothing", "FDR threshold"],
    "Value": [6.44, 5.98, 5.25, 3.289]
})

results
# Out:
#         Condition  Value
# 0  0 mm smoothing  6.440
# 1  5 mm smoothing  5.980
# 2  8 mm smoothing  5.250
# 3   FDR threshold  3.289

# %% [markdown]
# # Limitations
#
# - Single-subject first-level dataset limits population generalization
# - Public sample dataset is smaller than large consortium datasets
# - Only selected preprocessing parameters were varied
# - No external replication sample was included

# %% [markdown]
# # Future Directions
#
# - Extend to multi-subject group-level datasets
# - Compare additional preprocessing pipelines
# - Evaluate motion/confound regression strategies
# - Add cross-dataset reproducibility analyses
# - Explore machine learning prediction from task activation maps

# %% [markdown]
# # Conclusion
#
# Reliable neuroimaging findings depend not only on data quality, but also on informed analytical decisions. This project demonstrates that preprocessing parameters and thresholding choices can meaningfully shape task-fMRI results. Reproducible neuroscience therefore requires both technical execution and critical statistical reasoning.
